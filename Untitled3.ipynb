# %%
# Import libraries
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import altair as alt
import altair_saver 
import warnings
from vega_datasets import data

# Filter out the specific warning you want to ignore
warnings.filterwarnings("ignore", message="iteritems is deprecated and will be removed in a future version")

# %%
os.chdir('C://Users/pmarshal/Documents/golf_courses')
os.getcwd()
# Out:
# 'C:\\Users\\pmarshal\\Documents\\golf_courses'

# %%
course_master = pd.read_csv('data/master_golf_list.csv')

# %%
holes_18 = course_master.loc[course_master['length'] == 18]
courses = ['St Mellion GC -- Kernow', 'Mountain Brook GC', 'Stoneridge GC']
lows = holes_18.loc[holes_18['course_name'].isin(courses)]
lows
# Out:
#                  course_name         city    state                   country  \
# 632        Mountain Brook GC  Gold Canyon  Arizona  United States of America
# 662            Stoneridge GC    Blanchard    Idaho  United States of America
# 846  St Mellion GC -- Kernow     Plymouth  England            United Kingdom
#
#      latitude  longitude  year  length  personal_rating times_played  \
# 632    33.362   -111.468  2003      18              7.5            1
# 662    47.915   -116.754  2005      18              8.0            1
# 846    50.464     -4.274  2009      18              7.0            1
#
#      best_score
# 632        62.0
# 662        63.0
# 846        63.0

# %%
sorted_df = holes_18.sort_values(by='best_score')

# If you want to reset the index after sorting
sorted_df.reset_index(drop=True, inplace=True)

sorted_df.head(20)
# Out:
#                        course_name            city       state  \
# 0                  Chimney Rock GC            Napa  California
# 1                 Mission Hills GC       Kimberley          BC
# 2               Michaelbrook Ranch         Kelowna          BC
# 3                 Mission Creek GC         Kelowna          BC
# 4          Southampton Princess GC             NaN         NaN
# 5                     Pineridge GC        Kamloops          BC
# 6                  Coyote Creek GC          Surrey          BC
# 7                Mountain Brook GC     Gold Canyon     Arizona
# 8   Vintage Hills GC -- Two Eagles         Kelowna          BC
# 9                    Tsawwassen GC      Tsawwassen          BC
# 10            Palm Valley CC North    Palm Springs  California
# 11         St Mellion GC -- Kernow        Plymouth     England
# 12                   Arrowsmith GC        Qualicum          BC
# 13                        Wayne GC         Redmond  Washington
# 14                   Stoneridge GC       Blanchard       Idaho
# 15                  Cultus Lake GC     Cultus Lake          BC
# 16                Spring Valley GC        Milpitas  California
# 17  Capilano Golf and Country Club  West Vancouver          BC
# 18                   Cedar Hill GC        Victoria          BC
# 19                         Nile GC         Seattle  Washington
#
#                      country  latitude  longitude  year  length  \
# 0   United States of America    38.270   -122.313  1991      18
# 1                     Canada    49.670   -115.982  2021      18
# 2                     Canada    49.840   -119.475  1989      18
# 3                     Canada    49.858   -119.453  1988      18
# 4                    Bermuda    32.261    -64.845  1989      18
# 5                     Canada    50.754   -120.271  1993      18
# 6                     Canada    49.087   -122.797  1993      18
# 7   United States of America    33.362   -111.468  2003      18
# 8                     Canada    49.878   -119.518  2005      18
# 9                     Canada    49.009   -123.135  1995      18
# 10  United States of America    33.821   -116.408  1992      18
# 11            United Kingdom    50.464     -4.274  2009      18
# 12                    Canada    49.351   -124.462  2001      18
# 13  United States of America    47.676   -122.140  1988      18
# 14  United States of America    47.915   -116.754  2005      18
# 15                    Canada    49.054   -121.980  2007      18
# 16  United States of America    37.485   -121.882  2004      18
# 17                    Canada    49.354   -123.125  1965      18
# 18                    Canada    48.455   -123.345  1985      18
# 19  United States of America    47.662   -122.336  2011      18
#
#     personal_rating times_played  best_score
# 0               6.0            1        38.0
# 1               6.0            1        55.0
# 2               5.0            3        56.0
# 3               5.0            3        59.0
# 4               7.5            1        59.0
# 5               5.0            1        60.0
# 6               5.0            1        60.0
# 7               7.5            1        62.0
# 8               7.0            1        62.0
# 9               6.0            1        62.0
# 10              6.0            1        63.0
# 11              7.0            1        63.0
# 12              6.0            1        63.0
# 13              6.0            1        63.0
# 14              8.0            1        63.0
# 15              5.0            1        64.0
# 16              7.0            1        65.0
# 17             10.0         3000        65.0
# 18              6.0            2        65.0
# 19              6.5            1        66.0
