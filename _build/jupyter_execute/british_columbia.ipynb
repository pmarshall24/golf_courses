# %%
# Import libraries
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import altair as alt
import altair_saver 
import geopandas as gpd
from mpl_toolkits.basemap import Basemap
import folium
# Out:
# C:\Users\pmarshal\Anaconda3\lib\site-packages\geopandas\_compat.py:123: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# # The Old Country
# ### Gold Courses in the United Kingdom and Ireland

# %%
# Set working directory
os.chdir('C://Users/pmarshal/Documents/golf_course_book')
os.getcwd()
# Out:
# 'C:\\Users\\pmarshal\\Documents\\golf_course_book'

# %%
# Import data
course_master = pd.read_csv('data/master_golf_list.csv')
course_master.head()
# Out:
#                               course_name            city state  country  \
# 0  Grant Lucayan Golf Club -- Reef Course        Freeport   NaN  Bahamas
# 1                Bahamas Princess -- Ruby             NaN   NaN  Bahamas
# 2             Bahamas Princess -- Emerald        Freeport   NaN  Bahamas
# 3                    South Ocean Beach GC  New Providence   NaN  Bahamas
# 4                            Mid Ocean GC             NaN   NaN  Bermuda
#
#    latitude  longitude  year  length  personal_rating times_played  best_score
# 0    26.511 -78.652259  1993      18              7.5            1        83.0
# 1    26.523 -78.708000  1993      18              8.0            1        80.0
# 2    26.512 -78.701000  1993      18              7.0            1        79.0
# 3    25.009 -77.523000  1993      18              7.5            1        76.0
# 4    32.331 -64.694000  1989      18              9.5            1        74.0

# %%
uk_df = course_master.loc[(course_master['country'] == 'United Kingdom') | (course_master['country'] == 'Ireland')]
gdf_uk_courses = gpd.GeoDataFrame(uk_df, geometry=gpd.points_from_xy(uk_df.longitude, uk_df.latitude))
gdf_uk_courses
# Out:
#                                 course_name                city    state  \
# 806                         Sunningdale Old        Sunningdale   England
# 807                         Sunningdale New        Sunningdale   England
# 808                        Walton Heath Old  Walton on the hill  England
# 809                        Walton Heath New  Walton on the hill  England
# 810                          Wentworth West      Virginia Water  England
# ...                                     ...                 ...      ...
# 1002                    Chipping Sodbury GC    Chipping Sodbury  England
# 1003  Clwbb Golff Porth Llechog ( Bull Bay)              Amlwch    Wales
# 1004                            Aberdovy GC            Aberdyfi    Wales
# 1005                            Cardigan GC            Cardigan    Wales
# 1006                               Tenby GC               Tenby    Wales
#
#              country  latitude  longitude  year  length  personal_rating  \
# 806   United Kingdom    51.392     -0.627  1972      18             10.0
# 807   United Kingdom    51.392     -0.627  1972      18              9.0
# 808   United Kingdom    51.318     -0.242  1972      18              9.0
# 809   United Kingdom    51.318     -0.242  1972      18              9.0
# 810   United Kingdom    51.399     -0.567  1972      18              9.5
# ...              ...       ...        ...   ...     ...              ...
# 1002  United Kingdom    51.542     -2.427  2018      18              7.5
# 1003  United Kingdom    53.419     -4.383  2018      18              8.0
# 1004  United Kingdom    52.542     -4.049  2018      18              9.0
# 1005  United Kingdom    52.084     -4.652  2018      18              7.5
# 1006  United Kingdom    51.674     -4.707  2018      18              9.0
#
#      times_played  best_score                   geometry
# 806             3        80.0  POINT (-0.62700 51.39200)
# 807             3        79.0  POINT (-0.62700 51.39200)
# 808             1        84.0  POINT (-0.24200 51.31800)
# 809             1        83.0  POINT (-0.24200 51.31800)
# 810             1        86.0  POINT (-0.56700 51.39900)
# ...           ...         ...                        ...
# 1002            1        79.0  POINT (-2.42700 51.54200)
# 1003            1        75.0  POINT (-4.38300 53.41900)
# 1004            1        79.0  POINT (-4.04900 52.54200)
# 1005            1        78.0  POINT (-4.65200 52.08400)
# 1006            1        74.0  POINT (-4.70700 51.67400)
#
# [181 rows x 12 columns]

# %%
m = folium.Map(location=[53.6, -3.5], zoom_start=5.5)

# %%
for course in gdf_uk_courses["course_name"].unique():
    course_loc = gdf_uk_courses[gdf_uk_courses["course_name"]==course]
    folium.CircleMarker(
        location=[course_loc.latitude.values[0], course_loc.longitude.values[0]],
        tooltip = course_loc.course_name.values[0],
        radius = 4,
        color="blue",
        fill_color="red"
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5ce83c4a575718c5a3a91ae008de57c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5ce83c4a575718c5a3a91ae008de57c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5ce83c4a575718c5a3a91ae008de57c = L.map(
#                 &quot;map_f5ce83c4a575718c5a3a91ae008de57c&quot;,
#                 {
#                     center: [53.6, -3.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_41ad6814d6b443f017690631a4faba94 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f5ce83c4a575718c5a3a91ae008de57c);
#
#
#             var circle_marker_d85fe0964eb75615efecd9b71e0e5707 = L.circleMarker(
#                 [51.392, -0.627],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f5ce83c4a575718c5a3a91ae008de57c);
#
#
#             circle_marker_d85fe0964eb75615efecd9b71e0e5707.bindTooltip(
#                 `&lt;div&gt;
#                      Sunningdale Old
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_0a2aa95a63cf3709b95b1692ea559012 = L.circleMarker(
#                 [51.392, -0.627],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f5ce83c4a575718c5a3a91ae008de57c);
#
#
#             circle_marker_0a2aa95a63cf3709b95b1692ea559012.bindTooltip(
#                 `&lt;div&gt;
#                      Sunningdale New
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_b2c86758bde48a1a4367721b374a1cbe = L.circleMarker(
#                 [51.318, -0.242],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f5ce83c4a575718c5a3a91ae008de57c);
#
#
#             circle_marker_b2c86758bde48a1a4367721b374a1cbe.bindTooltip(
#                 `&lt;div&gt;
#                      Walton Heath Old
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_c209eda847d53a056e038a318dccfc3e = L.circleMarker(
#                 [51.318, -0.242],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f5ce83c4a575718c5a3a91ae008de57c);
#
#
#             circle_marker_c209eda847d53a056e038a318dccfc3e.bindTooltip(
#                 `&lt;div&gt;
#                      Walton Heath New
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_e145eac0479c967493b9bee71ba1a9b9 = L.circleMarker(
#                 [51.399, -0.567],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&
