# %%
# Import libraries
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import altair as alt
import altair_saver 
import geopandas as gpd
from mpl_toolkits.basemap import Basemap
import folium
# Out:
# C:\Users\pmarshal\Anaconda3\lib\site-packages\geopandas\_compat.py:123: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# # Regional Highlights
#
# The vast majority of golf courses played are in North America and the United Kingdom (plus Ireland). This section will zoom in on these two regions.
#
# ## North America
#
# Mike has played a grand total **717** different golf courses in Canada and the USA, with the vast majority located on the west coast and in Hawaii. Below is a map showing the location of all these courses. You can zoom and scroll, and hover over points to see the names of the golf courses.

# %% [markdown]
# ```{figure} img/pacific-dunes.jpg
# ---
# name: pacific_dunes
# ---
# 14th hole, Pacific Dunes Golf Course
# ```

# %%
# Set working directory
os.chdir('C://Users/pmarshal/Documents/golf_courses')
os.getcwd()
# Out:
# 'C:\\Users\\pmarshal\\Documents\\golf_courses'

# %%
# Import data
course_master = pd.read_csv('data/master_golf_list.csv')

# %%
can_usa_df = course_master.loc[(course_master['country'] == 'Canada') | (course_master['country'] == 'United States of America')]
gdf_na_courses = gpd.GeoDataFrame(can_usa_df, geometry=gpd.points_from_xy(can_usa_df.longitude, can_usa_df.latitude))

# %%
top_rated = can_usa_df.sort_values(by='personal_rating', ascending=False).head(20)
top_rated = top_rated.head(10)
top_rated
top_rated.to_csv('top_rated.csv', index=False)

# %%
filter_18 = can_usa_df.loc[can_usa_df['length'] == 18]
filter_rating = filter_18.loc[filter_18['personal_rating'] >= 7]
best_scores = filter_rating.sort_values(by='best_score', ascending=True).head(10)

# %%
m = folium.Map(location=[49.7, -117.0], zoom_start=5)

# %%
for course in gdf_na_courses["course_name"].unique():
    course_loc = gdf_na_courses[gdf_na_courses["course_name"]==course]
    folium.CircleMarker(
        location=[course_loc.latitude.values[0], course_loc.longitude.values[0]],
        tooltip = course_loc.course_name.values[0],
        radius = 4,
        color="blue",
        fill_color="red"
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56254cdacdb64f9522284c610215b374 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56254cdacdb64f9522284c610215b374&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56254cdacdb64f9522284c610215b374 = L.map(
#                 &quot;map_56254cdacdb64f9522284c610215b374&quot;,
#                 {
#                     center: [49.7, -117.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4bd1a0430f7e66d30a028fb4be414e5f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_56254cdacdb64f9522284c610215b374);
#
#
#             var circle_marker_886fafc7a2357252b8156a196acc9d1b = L.circleMarker(
#                 [50.736, -120.267],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_56254cdacdb64f9522284c610215b374);
#
#
#             circle_marker_886fafc7a2357252b8156a196acc9d1b.bindTooltip(
#                 `&lt;div&gt;
#                      Canoe creek
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_997d8a6e1b846bb273aa61fe1e3ac35e = L.circleMarker(
#                 [50.706, -119.255],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_56254cdacdb64f9522284c610215b374);
#
#
#             circle_marker_997d8a6e1b846bb273aa61fe1e3ac35e.bindTooltip(
#                 `&lt;div&gt;
#                      Salmon Arm GC
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_9bc809e91fd4e6593979ed5f9e9073fe = L.circleMarker(
#                 [49.149, -125.911],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_56254cdacdb64f9522284c610215b374);
#
#
#             circle_marker_9bc809e91fd4e6593979ed5f9e9073fe.bindTooltip(
#                 `&lt;div&gt;
#                      Long Beach GC
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_44288a76a02e09500423b0ae77ff8cdf = L.circleMarker(
#                 [49.354, -123.125],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_56254cdacdb64f9522284c610215b374);
#
#
#             circle_marker_44288a76a02e09500423b0ae77ff8cdf.bindTooltip(
#                 `&lt;div&gt;
#                      Capilano Golf and Country Club
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_1c71c1d2654ad7d172415c68895b798d = L.circleMarker(
#                 [49.321, -122.979],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;,

# %% [markdown]
# ## The United Kingdom and Ireland
#
# It's generally accepted that the modern game of golf originated in Scotland sometime in the middle ages. The first documented mention of the game in Scotland appears in a 1457 Act of the Scottish Parliament, issued by King James II, prohibiting the play of *gowf* as it was a distraction from archery practice for military purposes. Golf did gain popularity among royals and nobles in the coming decades; however, it was not until the late 1800's when the popularity of golf really boomed.
#
# The United Kingdom and Ireland are blessed with many of the best golf courses in the world. And many of these are classic links courses dotting the coast. Five of the top 10 best ranked golf courses in the world are in Ireland or the UK. It is truly a golf mecca.

# %% [markdown]
# ```{figure} img/st-andrews-old.jpg
# ---
# name: st-andrews
# ---
# St. Andrews -- Old Course
# ```

# %%
uk_df = course_master.loc[(course_master['country'] == 'United Kingdom') | (course_master['country'] == 'Ireland')]
gdf_uk_courses = gpd.GeoDataFrame(uk_df, geometry=gpd.points_from_xy(uk_df.longitude, uk_df.latitude))

# %%
# Import data
top_10 = pd.read_csv('top_10.csv', index_col='Course Name')
#top_10 = top_10.reset_index()
top_10
# Out:
#                                       City     Country  Personal Rating  \
# Course Name
# Royal County Down GC             Newcastle  N. Ireland               11
# Sunningdale Old               Sunningdale      England               10
# Ballybunion Old                Ballybunion     Ireland               10
# Turnberry -- Ailsa               Turnberry    Scotland               10
# Muirfield                          Gullane    Scotland               10
# Royal Portrush GC -- Dunluce      Portrush  N. Ireland               10
# The Old Course                  St Andrews    Scotland               10
# Royal Dornoch GC                   Dornoch    Scotland               10
# Carne GC                         Belmullet     Ireland               10
# Royal Birkdale                   Southport     England               10
#
#                               Best Score  Par  Course Rating  Slope
# Course Name
# Royal County Down GC                  74   71           75.0    142
# Sunningdale Old                       80   70           72.7    139
# Ballybunion Old                       72   71           74.5    131
# Turnberry -- Ailsa                    82   71           77.2    139
# Muirfield                             86   71           70.4    132
# Royal Portrush GC -- Dunluce          75   72           76.0    140
# The Old Course                        76   72           73.1    132
# Royal Dornoch GC                      77   70           73.2    136
# Carne GC                              81   72           72.6    124
# Royal Birkdale                        81   70           74.9    147

# %%
m2 = folium.Map(location=[53.6, -3.5], zoom_start=5.5)

# %%
for course in gdf_uk_courses["course_name"].unique():
    course_loc = gdf_uk_courses[gdf_uk_courses["course_name"]==course]
    folium.CircleMarker(
        location=[course_loc.latitude.values[0], course_loc.longitude.values[0]],
        tooltip = course_loc.course_name.values[0],
        radius = 4,
        color="blue",
        fill_color="red"
    ).add_to(m2)
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f56a7da3060fc324ea81e4663c19cec5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f56a7da3060fc324ea81e4663c19cec5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f56a7da3060fc324ea81e4663c19cec5 = L.map(
#                 &quot;map_f56a7da3060fc324ea81e4663c19cec5&quot;,
#                 {
#                     center: [53.6, -3.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b86203331f10780839c080035919eb6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f56a7da3060fc324ea81e4663c19cec5);
#
#
#             var circle_marker_23062688ff336f05a6268161ff7172a4 = L.circleMarker(
#                 [51.392, -0.627],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f56a7da3060fc324ea81e4663c19cec5);
#
#
#             circle_marker_23062688ff336f05a6268161ff7172a4.bindTooltip(
#                 `&lt;div&gt;
#                      Sunningdale Old
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_3f5eb1879270cb70852360e7a0334139 = L.circleMarker(
#                 [51.392, -0.627],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f56a7da3060fc324ea81e4663c19cec5);
#
#
#             circle_marker_3f5eb1879270cb70852360e7a0334139.bindTooltip(
#                 `&lt;div&gt;
#                      Sunningdale New
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_acb733638f62425c3e14e8974234d637 = L.circleMarker(
#                 [51.318, -0.242],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f56a7da3060fc324ea81e4663c19cec5);
#
#
#             circle_marker_acb733638f62425c3e14e8974234d637.bindTooltip(
#                 `&lt;div&gt;
#                      Walton Heath Old
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_e3a20032eb102369d27a109bd132c01e = L.circleMarker(
#                 [51.318, -0.242],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f56a7da3060fc324ea81e4663c19cec5);
#
#
#             circle_marker_e3a20032eb102369d27a109bd132c01e.bindTooltip(
#                 `&lt;div&gt;
#                      Walton Heath New
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_b87435ae63eb156664070dd004db00d0 = L.circleMarker(
#                 [51.399, -0.567],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&
