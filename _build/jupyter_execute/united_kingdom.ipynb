# %%
# Import libraries
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import altair as alt
import altair_saver 
import geopandas as gpd
from mpl_toolkits.basemap import Basemap
import folium
# Out:
# C:\Users\pmarshal\Anaconda3\lib\site-packages\geopandas\_compat.py:123: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# ```{figure} img/st-andrews-old.jpg
# ---
# name: st-andrews
# ---
# St. Andrews -- Old Course
# ```

# %% [markdown]
# # Spotlight on *The Old Country*
# ### Golf courses played in the United Kingdom and Ireland

# %%
# Set working directory
os.chdir('C://Users/pmarshal/Documents/golf_course_book')
os.getcwd()
# Out:
# 'C:\\Users\\pmarshal\\Documents\\golf_course_book'

# %%
# Import data
course_master = pd.read_csv('data/master_golf_list.csv')

# %%
uk_df = course_master.loc[(course_master['country'] == 'United Kingdom') | (course_master['country'] == 'Ireland')]
gdf_uk_courses = gpd.GeoDataFrame(uk_df, geometry=gpd.points_from_xy(uk_df.longitude, uk_df.latitude))

# %% [markdown]
# ## Top-10 Rated Golf Courses
# These courses were rated the highest among the 181 total courses played in the UK and Ireland.

# %%
# Import data
top_10 = pd.read_csv('top_10.csv')
top_10
# Out:
#                     Course Name          City     Country  Personal Rating  \
# 0          Royal County Down GC     Newcastle  N. Ireland               11
# 1               Sunningdale Old  Sunningdale      England               10
# 2               Ballybunion Old   Ballybunion     Ireland               10
# 3            Turnberry -- Ailsa     Turnberry    Scotland               10
# 4                     Muirfield       Gullane    Scotland               10
# 5  Royal Portrush GC -- Dunluce      Portrush  N. Ireland               10
# 6                The Old Course    St Andrews    Scotland               10
# 7              Royal Dornoch GC       Dornoch    Scotland               10
# 8                      Carne GC     Belmullet     Ireland               10
# 9                Royal Birkdale     Southport     England               10
#
#    Best Score  Par  Course Rating  Slope
# 0          74   71           75.0    142
# 1          80   70           72.7    139
# 2          72   71           74.5    131
# 3          82   71           77.2    139
# 4          86   71           70.4    132
# 5          75   72           76.0    140
# 6          76   72           73.1    132
# 7          77   70           73.2    136
# 8          81   72           72.6    124
# 9          81   70           74.9    147

# %% [markdown]
# Below is a map of golf courses played in the United Kingdom and Ireland. You can hover over each point to see the name of the golf course. You can also zoom and scroll as desired.

# %%
m = folium.Map(location=[53.6, -3.5], zoom_start=5.5)

# %%
for course in gdf_uk_courses["course_name"].unique():
    course_loc = gdf_uk_courses[gdf_uk_courses["course_name"]==course]
    folium.CircleMarker(
        location=[course_loc.latitude.values[0], course_loc.longitude.values[0]],
        tooltip = course_loc.course_name.values[0],
        radius = 4,
        color="blue",
        fill_color="red"
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca35152f8d6f236b4a5afce88e8ecaa3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca35152f8d6f236b4a5afce88e8ecaa3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca35152f8d6f236b4a5afce88e8ecaa3 = L.map(
#                 &quot;map_ca35152f8d6f236b4a5afce88e8ecaa3&quot;,
#                 {
#                     center: [53.6, -3.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7d27bc15604be98fafd1d0fae99fb8a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ca35152f8d6f236b4a5afce88e8ecaa3);
#
#
#             var circle_marker_b6417715dc237e39cdab06c10cf02f4b = L.circleMarker(
#                 [51.392, -0.627],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ca35152f8d6f236b4a5afce88e8ecaa3);
#
#
#             circle_marker_b6417715dc237e39cdab06c10cf02f4b.bindTooltip(
#                 `&lt;div&gt;
#                      Sunningdale Old
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_dbb005ad289ce75e12f70f06d8865b40 = L.circleMarker(
#                 [51.392, -0.627],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ca35152f8d6f236b4a5afce88e8ecaa3);
#
#
#             circle_marker_dbb005ad289ce75e12f70f06d8865b40.bindTooltip(
#                 `&lt;div&gt;
#                      Sunningdale New
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_8e003676a513553729f4f3751e459650 = L.circleMarker(
#                 [51.318, -0.242],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ca35152f8d6f236b4a5afce88e8ecaa3);
#
#
#             circle_marker_8e003676a513553729f4f3751e459650.bindTooltip(
#                 `&lt;div&gt;
#                      Walton Heath Old
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_0d6890768011d2dda1acde1a7e109446 = L.circleMarker(
#                 [51.318, -0.242],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ca35152f8d6f236b4a5afce88e8ecaa3);
#
#
#             circle_marker_0d6890768011d2dda1acde1a7e109446.bindTooltip(
#                 `&lt;div&gt;
#                      Walton Heath New
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_23b24158c71eeafb92e3b354e65cfe7a = L.circleMarker(
#                 [51.399, -0.567],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&
