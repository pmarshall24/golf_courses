# %%
# Import libraries
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import altair as alt
import altair_saver 
import geopandas as gpd
from mpl_toolkits.basemap import Basemap
import folium

# %% [markdown]
# # Spotlight on British Columbia

# %%
# Set working directory
os.chdir('C://Users/pmarshal/Documents/golf_course_book')
os.getcwd()
# Out:
# 'C:\\Users\\pmarshal\\Documents\\golf_course_book'

# %%
# Import data
course_master = pd.read_csv('data/master_golf_list.csv')
course_master.head()
# Out:
#                               course_name            city state  country  \
# 0  Grant Lucayan Golf Club -- Reef Course        Freeport   NaN  Bahamas
# 1                Bahamas Princess -- Ruby             NaN   NaN  Bahamas
# 2             Bahamas Princess -- Emerald        Freeport   NaN  Bahamas
# 3                    South Ocean Beach GC  New Providence   NaN  Bahamas
# 4                            Mid Ocean GC             NaN   NaN  Bermuda
#
#    latitude  longitude  year  length  personal_rating times_played  best_score
# 0    26.511 -78.652259  1993      18              7.5            1        83.0
# 1    26.523 -78.708000  1993      18              8.0            1        80.0
# 2    26.512 -78.701000  1993      18              7.0            1        79.0
# 3    25.009 -77.523000  1993      18              7.5            1        76.0
# 4    32.331 -64.694000  1989      18              9.5            1        74.0

# %%
can_usa_df = course_master.loc[(course_master['country'] == 'Canada') | (course_master['country'] == 'United States of America')]
gdf_na_courses = gpd.GeoDataFrame(can_usa_df, geometry=gpd.points_from_xy(can_usa_df.longitude, can_usa_df.latitude))

# %%
m = folium.Map(location=[49.7, -117.0], zoom_start=5)

# %%
for course in gdf_na_courses["course_name"].unique():
    course_loc = gdf_na_courses[gdf_na_courses["course_name"]==course]
    folium.CircleMarker(
        location=[course_loc.latitude.values[0], course_loc.longitude.values[0]],
        tooltip = course_loc.course_name.values[0],
        radius = 4,
        color="blue",
        fill_color="red"
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a69f7e2cc82d910c7d1194218ba145a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a69f7e2cc82d910c7d1194218ba145a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a69f7e2cc82d910c7d1194218ba145a5 = L.map(
#                 &quot;map_a69f7e2cc82d910c7d1194218ba145a5&quot;,
#                 {
#                     center: [49.7, -117.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e2914151704bd1d2dade86e9c3d497c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a69f7e2cc82d910c7d1194218ba145a5);
#
#
#             var circle_marker_2923d1d376d77620bb975d622c6fbb6d = L.circleMarker(
#                 [50.736, -120.267],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a69f7e2cc82d910c7d1194218ba145a5);
#
#
#             circle_marker_2923d1d376d77620bb975d622c6fbb6d.bindTooltip(
#                 `&lt;div&gt;
#                      Canoe creek
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_c8a12810b5fcaf5a53c4284445b4c114 = L.circleMarker(
#                 [50.706, -119.255],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a69f7e2cc82d910c7d1194218ba145a5);
#
#
#             circle_marker_c8a12810b5fcaf5a53c4284445b4c114.bindTooltip(
#                 `&lt;div&gt;
#                      Salmon Arm GC
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_e69593c48b9b9a47c2e4d8424e282194 = L.circleMarker(
#                 [49.149, -125.911],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a69f7e2cc82d910c7d1194218ba145a5);
#
#
#             circle_marker_e69593c48b9b9a47c2e4d8424e282194.bindTooltip(
#                 `&lt;div&gt;
#                      Long Beach GC
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_e6f6fdb31ec14b29539627ec9a5058b9 = L.circleMarker(
#                 [49.354, -123.125],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a69f7e2cc82d910c7d1194218ba145a5);
#
#
#             circle_marker_e6f6fdb31ec14b29539627ec9a5058b9.bindTooltip(
#                 `&lt;div&gt;
#                      Capilano Golf and Country Club
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_03bdcd7d7d5f6c0840495cb8034bb690 = L.circleMarker(
#                 [49.321, -122.979],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;,
